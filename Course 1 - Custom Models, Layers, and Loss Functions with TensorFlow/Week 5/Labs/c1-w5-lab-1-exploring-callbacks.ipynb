# %% [markdown]
# # Ungraded Lab: Introduction to Keras callbacks

# %% [markdown]
# ## Model methods that take callbacks

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
    # %tensorflow_version only exists in Colab.
    # %tensorflow_version 2.x
except Exception:
    pass

import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import io
from PIL import Image

from tensorflow.keras.callbacks import TensorBoard, EarlyStopping, LearningRateScheduler, ModelCheckpoint, CSVLogger, ReduceLROnPlateau
# %load_ext tensorboard

import os
import matplotlib.pylab as plt
import numpy as np
import math
import datetime
import pandas as pd

print("Version: ", tf.__version__)
tf.get_logger().setLevel('INFO')
# Out:
# 2024-08-04 13:20:47.595509: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-04 13:20:47.595624: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-04 13:20:47.737707: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Version:  2.15.0

# %% [markdown]
# # Examples of Keras callback applications
# The following section will guide you through creating simple [Callback](https://keras.io/api/callbacks/) applications.

# %%
# Download and prepare the horses or humans dataset

# horses_or_humans 3.0.0 has already been downloaded for you
path = "./tensorflow_datasets"
splits, info = tfds.load('horses_or_humans', data_dir=path, as_supervised=True, with_info=True, split=['train[:80%]', 'train[80%:]', 'test'])

(train_examples, validation_examples, test_examples) = splits

num_examples = info.splits['train'].num_examples
num_classes = info.features['label'].num_classes
# Out:
# Downloading and preparing dataset 153.59 MiB (download: 153.59 MiB, generated: Unknown size, total: 153.59 MiB) to ./tensorflow_datasets/horses_or_humans/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/1027 [00:00<?, ? examples/s]
# Shuffling tensorflow_datasets/horses_or_humans/3.0.0.incompleteI32WFD/horses_or_humans-train.tfrecord*...:   0…
# Generating test examples...:   0%|          | 0/256 [00:00<?, ? examples/s]
# Shuffling tensorflow_datasets/horses_or_humans/3.0.0.incompleteI32WFD/horses_or_humans-test.tfrecord*...:   0%…
# Dataset horses_or_humans downloaded and prepared to ./tensorflow_datasets/horses_or_humans/3.0.0. Subsequent calls will reuse this data.

# %%
SIZE = 150 #@param {type:"slider", min:64, max:300, step:1}
IMAGE_SIZE = (SIZE, SIZE)

# %%
def format_image(image, label):
  image = tf.image.resize(image, IMAGE_SIZE) / 255.0
  return  image, label

# %%
BATCH_SIZE = 32 #@param {type:"integer"}

# %%
train_batches = train_examples.shuffle(num_examples // 4).map(format_image).batch(BATCH_SIZE).prefetch(1)
validation_batches = validation_examples.map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batches = test_examples.map(format_image).batch(1)

# %%
for image_batch, label_batch in train_batches.take(1):
  pass

image_batch.shape
# Out:
# TensorShape([32, 150, 150, 3])

# %%
def build_model(dense_units, input_shape=IMAGE_SIZE + (3,)):
  model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=input_shape),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
      tf.keras.layers.MaxPooling2D(2, 2),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(dense_units, activation='relu'),
      tf.keras.layers.Dense(2, activation='softmax')
  ])
  return model

# %% [markdown]
# ## [TensorBoard](https://keras.io/api/callbacks/tensorboard/)
#
# Enable visualizations for TensorBoard.

# %%
# !rm -rf logs
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir)

model.fit(train_batches, 
          epochs=10, 
          validation_data=validation_batches, 
          callbacks=[tensorboard_callback])
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 2024-08-04 13:21:10.114370: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 43808: 7.10448, expected 6.11694
# 2024-08-04 13:21:10.114441: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 43809: 7.52163, expected 6.53409
# 2024-08-04 13:21:10.114452: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 43810: 7.97066, expected 6.98313
# 2024-08-04 13:21:10.114460: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 43811: 7.81967, expected 6.83214
# 2024-08-04 13:21:10.114469: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 43812: 7.66175, expected 6.67421
# 2024-08-04 13:21:10.114478: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 
width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b58b61225fdb1473");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## [Model Checkpoint](https://keras.io/api/callbacks/model_checkpoint/)
#
# Callback to save the Keras model or model weights at some frequency.

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=5, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[ModelCheckpoint('weights.{epoch:02d}-{val_loss:.2f}.keras', verbose=1),
          ])
# Out:
# Epoch 1/5
#
# Epoch 1: saving model to weights.01-0.55.keras
# 26/26 - 3s - 123ms/step - accuracy: 0.6703 - loss: 0.6172 - val_accuracy: 0.7171 - val_loss: 0.5549
# Epoch 2/5
#
# Epoch 2: saving model to weights.02-0.52.keras
# 26/26 - 0s - 13ms/step - accuracy: 0.7798 - loss: 0.5154 - val_accuracy: 0.7024 - val_loss: 0.5169
# Epoch 3/5
#
# Epoch 3: saving model to weights.03-0.36.keras
# 26/26 - 0s - 13ms/step - accuracy: 0.8431 - loss: 0.4258 - val_accuracy: 0.9268 - val_loss: 0.3633
# Epoch 4/5
#
# Epoch 4: saving model to weights.04-0.31.keras
# 26/26 - 0s - 13ms/step - accuracy: 0.8382 - loss: 0.4019 - val_accuracy: 0.9317 - val_loss: 0.3141
# Epoch 5/5
#
# Epoch 5: saving model to weights.05-0.26.keras
# 26/26 - 0s - 13ms/step - accuracy: 0.8893 - loss: 0.3229 - val_accuracy: 0.9561 - val_loss: 0.2622

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=1, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[ModelCheckpoint('/kaggle/working/weights.04-0.31.keras', verbose=1)
          ])
# Out:
# Epoch 1: saving model to /kaggle/working/weights.04-0.31.keras
# 26/26 - 3s - 100ms/step - accuracy: 0.6557 - loss: 0.6274 - val_accuracy: 0.7659 - val_loss: 0.5710

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=2, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[ModelCheckpoint('model.keras', verbose=1)
          ])
# Out:
# Epoch 1/2
#
# Epoch 1: saving model to model.keras
# 26/26 - 2s - 96ms/step - accuracy: 0.6618 - loss: 0.6213 - val_accuracy: 0.8293 - val_loss: 0.5172
# Epoch 2/2
#
# Epoch 2: saving model to model.keras
# 26/26 - 0s - 13ms/step - accuracy: 0.7506 - loss: 0.5107 - val_accuracy: 0.7220 - val_loss: 0.4948

# %% [markdown]
# ## [Early stopping](https://keras.io/api/callbacks/early_stopping/)
#
# Stop training when a monitored metric has stopped improving.

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=50, 
          validation_data=validation_batches, 
          verbose=2,
          callbacks=[EarlyStopping(
              patience=3,
              min_delta=0.05,
              baseline=0.8,
              mode='min',
              monitor='val_loss',
              restore_best_weights=True,
              verbose=1)
          ])
# Out:
# Epoch 1/50
# 26/26 - 2s - 93ms/step - accuracy: 0.6119 - loss: 0.6528 - val_accuracy: 0.6244 - val_loss: 0.5916
# Epoch 2/50
# 26/26 - 0s - 9ms/step - accuracy: 0.7336 - loss: 0.5086 - val_accuracy: 0.8439 - val_loss: 0.4239
# Epoch 3/50
# 26/26 - 0s - 9ms/step - accuracy: 0.8017 - loss: 0.4395 - val_accuracy: 0.8634 - val_loss: 0.3880
# Epoch 4/50
# 26/26 - 0s - 10ms/step - accuracy: 0.8418 - loss: 0.3657 - val_accuracy: 0.8976 - val_loss: 0.3121
# Epoch 5/50
# 26/26 - 0s - 9ms/step - accuracy: 0.8625 - loss: 0.3270 - val_accuracy: 0.9024 - val_loss: 0.2800
# Epoch 6/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9088 - loss: 0.2806 - val_accuracy: 0.9268 - val_loss: 0.2341
# Epoch 7/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9282 - loss: 0.2427 - val_accuracy: 0.8098 - val_loss: 0.3902
# Epoch 8/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9404 - loss: 0.2063 - val_accuracy: 0.9854 - val_loss: 0.1545
# Epoch 9/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9526 - loss: 0.1760 - val_accuracy: 0.9805 - val_loss: 0.1273
# Epoch 10/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9477 - loss: 0.1932 - val_accuracy: 0.9561 - val_loss: 0.1398
# Epoch 11/50
# 26/26 - 0s - 10ms/step - accuracy: 0.9611 - loss: 0.1425 - val_accuracy: 0.9805 - val_loss: 0.1019
# Epoch 12/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9732 - loss: 0.1148 - val_accuracy: 0.9610 - val_loss: 0.1043
# Epoch 13/50
# 26/26 - 0s - 9ms/step - accuracy: 0.9769 - loss: 0.1161 - val_accuracy: 0.9902 - val_loss: 0.0777
# Epoch 14/50
# 26/26 - 0s - 10ms/step - accuracy: 0.9818 - loss: 0.0861 - val_accuracy: 0.9561 - val_loss: 0.1024
# Epoch 14: early stopping
# Restoring model weights from the end of the best epoch: 11.

# %% [markdown]
# ## [CSV Logger](https://keras.io/api/callbacks/csv_logger/)
#
# Callback that streams epoch results to a CSV file.

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
csv_file = 'training.csv'

model.fit(train_batches, 
          epochs=5, 
          validation_data=validation_batches, 
          callbacks=[CSVLogger(csv_file)
          ])
# Out:
# Epoch 1/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - accuracy: 0.5807 - loss: 0.6618 - val_accuracy: 0.6488 - val_loss: 0.6281
# Epoch 2/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7031 - loss: 0.6047 - val_accuracy: 0.7073 - val_loss: 0.5829
# Epoch 3/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7587 - loss: 0.5562 - val_accuracy: 0.8537 - val_loss: 0.5146
# Epoch 4/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7799 - loss: 0.5173 - val_accuracy: 0.8976 - val_loss: 0.4705
# Epoch 5/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8154 - loss: 0.4850 - val_accuracy: 0.9073 - val_loss: 0.4346

# %%
pd.read_csv(csv_file).head()
# Out:
#    epoch  accuracy      loss  val_accuracy  val_loss
# 0      0  0.627737  0.647765      0.648780  0.628051
# 1      1  0.710462  0.597093      0.707317  0.582894
# 2      2  0.762774  0.549425      0.853659  0.514637
# 3      3  0.779805  0.520654      0.897561  0.470471
# 4      4  0.801703  0.483262      0.907317  0.434639

# %% [markdown]
# ## [Learning Rate Scheduler](https://keras.io/api/callbacks/learning_rate_scheduler/)
#
# Updates the learning rate during training.

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
def step_decay(epoch):
	initial_lr = 0.01
	drop = 0.5
	epochs_drop = 1
	lr = initial_lr * math.pow(drop, math.floor((1+epoch)/epochs_drop))
	return lr

model.fit(train_batches, 
          epochs=5, 
          validation_data=validation_batches, 
          callbacks=[LearningRateScheduler(step_decay, verbose=1),
                    TensorBoard(log_dir='./log_dir')])
# Out:
# Epoch 1: LearningRateScheduler setting learning rate to 0.005.
# Epoch 1/5
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - accuracy: 0.5603 - loss: 0.6678 - val_accuracy: 0.6976 - val_loss: 0.6195 - learning_rate: 0.0050
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.0025.
# Epoch 2/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7488 - loss: 0.5949 - val_accuracy: 0.8439 - val_loss: 0.5863 - learning_rate: 0.0025
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00125.
# Epoch 3/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8158 - loss: 0.5661 - val_accuracy: 0.9024 - val_loss: 0.5669 - learning_rate: 0.0012
#
# Epoch 4: LearningRateScheduler setting learning rate to 0.000625.
# Epoch 4/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8614 - loss: 0.5606 - val_accuracy: 0.8000 - val_loss: 0.5690 - learning_rate: 6.2500e-04
#
# Epoch 5: LearningRateScheduler setting learning rate to 0.0003125.
# Epoch 5/5
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8299 - loss: 0.5517 - val_accuracy: 0.8439 - val_loss: 0.5634 - learning_rate: 3.1250e-04

# %%
# %tensorboard --logdir log_dir
# Out:
#       <iframe id="tensorboard-frame-62876cd21a06f4c8" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-62876cd21a06f4c8");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# ## [ReduceLROnPlateau](https://keras.io/api/callbacks/reduce_lr_on_plateau/)
#
# Reduce learning rate when a metric has stopped improving.

# %%
model = build_model(dense_units=256)
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy', 
    metrics=['accuracy'])
  
model.fit(train_batches, 
          epochs=50, 
          validation_data=validation_batches, 
          callbacks=[ReduceLROnPlateau(monitor='val_loss', 
                                       factor=0.2, verbose=1,
                                       patience=1, min_lr=0.001),
                     TensorBoard(log_dir='./log_dir')])
# Out:
# Epoch 1/50
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - accuracy: 0.5375 - loss: 0.7123 - val_accuracy: 0.8000 - val_loss: 0.5737 - learning_rate: 0.0100
# Epoch 2/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8098 - loss: 0.5370 - val_accuracy: 0.8927 - val_loss: 0.4636 - learning_rate: 0.0100
# Epoch 3/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8047 - loss: 0.4873 - val_accuracy: 0.9073 - val_loss: 0.4304 - learning_rate: 0.0100
# Epoch 4/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8857 - loss: 0.4033 - val_accuracy: 0.8732 - val_loss: 0.3545 - learning_rate: 0.0100
# Epoch 5/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8789 - loss: 0.3544 - val_accuracy: 0.9317 - val_loss: 0.2932 - learning_rate: 0.0100
# Epoch 6/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8945 - loss: 0.2995 - val_accuracy: 0.9561 - val_loss: 0.2432 - learning_rate: 0.0100
# Epoch 7/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9325 - loss: 0.2462 - val_accuracy: 0.9463 - val_loss: 0.1972 - learning_rate: 0.0100
# Epoch 8/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9474 - loss: 0.2068 - val_accuracy: 0.9756 - val_loss: 0.1748 - learning_rate: 0.0100
# Epoch 9/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9586 - loss: 0.1657 - val_accuracy: 0.9902 - val_loss: 0.1320 - learning_rate: 0.0100
# Epoch 10/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9730 - loss: 0.1353 - val_accuracy: 0.9854 - val_loss: 0.1208 - learning_rate: 0.0100
# Epoch 11/50
# 21/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9663 - loss: 0.1478
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9673 - loss: 0.1430 - val_accuracy: 0.9366 - val_loss: 0.1696 - learning_rate: 0.0100
# Epoch 12/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9778 - loss: 0.1052 - val_accuracy: 0.9902 - val_loss: 0.0902 - learning_rate: 0.0020
# Epoch 13/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9849 - loss: 0.0891 - val_accuracy: 0.9854 - val_loss: 0.0891 - learning_rate: 0.0020
# Epoch 14/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9837 - loss: 0.0869 - val_accuracy: 0.9854 - val_loss: 0.0870 - learning_rate: 0.0020
# Epoch 15/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9830 - loss: 0.0826 - val_accuracy: 0.9854 - val_loss: 0.0858 - learning_rate: 0.0020
# Epoch 16/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9844 - loss: 0.0794 - val_accuracy: 0.9854 - val_loss: 0.0847 - learning_rate: 0.0020
# Epoch 17/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9880 - loss: 0.0738 - val_accuracy: 0.9902 - val_loss: 0.0782 - learning_rate: 0.0020
# Epoch 18/50
# 22/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9844 - loss: 0.0839
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.001.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9842 - loss: 0.0831 - val_accuracy: 0.9854 - val_loss: 0.0816 - learning_rate: 0.0020
# Epoch 19/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9871 - loss: 0.0718 - val_accuracy: 0.9902 - val_loss: 0.0779 - learning_rate: 0.0010
# Epoch 20/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9878 - loss: 0.0801 - val_accuracy: 0.9902 - val_loss: 0.0755 - learning_rate: 0.0010
# Epoch 21/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9884 - loss: 0.0757 - val_accuracy: 0.9902 - val_loss: 0.0759 - learning_rate: 0.0010
# Epoch 22/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9857 - loss: 0.0725 - val_accuracy: 0.9902 - val_loss: 0.0752 - learning_rate: 0.0010
# Epoch 23/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - loss: 0.0687 - val_accuracy: 0.9902 - val_loss: 0.0733 - learning_rate: 0.0010
# Epoch 24/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9881 - loss: 0.0687 - val_accuracy: 0.9902 - val_loss: 0.0716 - learning_rate: 0.0010
# Epoch 25/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9848 - loss: 0.0746 - val_accuracy: 0.9902 - val_loss: 0.0722 - learning_rate: 0.0010
# Epoch 26/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9895 - loss: 0.0671 - val_accuracy: 0.9902 - val_loss: 0.0713 - learning_rate: 0.0010
# Epoch 27/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9871 - loss: 0.0750 - val_accuracy: 0.9902 - val_loss: 0.0705 - learning_rate: 0.0010
# Epoch 28/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9898 - loss: 0.0675 - val_accuracy: 0.9902 - val_loss: 0.0697 - learning_rate: 0.0010
# Epoch 29/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9909 - loss: 0.0661 - val_accuracy: 0.9902 - val_loss: 0.0696 - learning_rate: 0.0010
# Epoch 30/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9895 - loss: 0.0622 - val_accuracy: 0.9902 - val_loss: 0.0696 - learning_rate: 0.0010
# Epoch 31/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9858 - loss: 0.0640 - val_accuracy: 0.9902 - val_loss: 0.0679 - learning_rate: 0.0010
# Epoch 32/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9863 - loss: 0.0690 - val_accuracy: 0.9902 - val_loss: 0.0668 - learning_rate: 0.0010
# Epoch 33/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9875 - loss: 0.0666 - val_accuracy: 0.9902 - val_loss: 0.0664 - learning_rate: 0.0010
# Epoch 34/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9878 - loss: 0.0641 - val_accuracy: 0.9902 - val_loss: 0.0645 - learning_rate: 0.0010
# Epoch 35/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9877 - loss: 0.0600 - val_accuracy: 0.9902 - val_loss: 0.0647 - learning_rate: 0.0010
# Epoch 36/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9928 - loss: 0.0548 - val_accuracy: 0.9854 - val_loss: 0.0656 - learning_rate: 0.0010
# Epoch 37/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9904 - loss: 0.0575 - val_accuracy: 0.9902 - val_loss: 0.0641 - learning_rate: 0.0010
# Epoch 38/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9920 - loss: 0.0601 - val_accuracy: 0.9854 - val_loss: 0.0651 - learning_rate: 0.0010
# Epoch 39/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9906 - loss: 0.0617 - val_accuracy: 0.9854 - val_loss: 0.0636 - learning_rate: 0.0010
# Epoch 40/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - loss: 0.0562 - val_accuracy: 0.9902 - val_loss: 0.0622 - learning_rate: 0.0010
# Epoch 41/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9908 - loss: 0.0508 - val_accuracy: 0.9902 - val_loss: 0.0618 - learning_rate: 0.0010
# Epoch 42/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9902 - loss: 0.0577 - val_accuracy: 0.9854 - val_loss: 0.0619 - learning_rate: 0.0010
# Epoch 43/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9873 - loss: 0.0559 - val_accuracy: 0.9854 - val_loss: 0.0618 - learning_rate: 0.0010
# Epoch 44/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9927 - loss: 0.0546 - val_accuracy: 0.9854 - val_loss: 0.0606 - learning_rate: 0.0010
# Epoch 45/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9879 - loss: 0.0565 - val_accuracy: 0.9902 - val_loss: 0.0587 - learning_rate: 0.0010
# Epoch 46/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9951 - loss: 0.0556 - val_accuracy: 0.9805 - val_loss: 0.0606 - learning_rate: 0.0010
# Epoch 47/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9910 - loss: 0.0499 - val_accuracy: 0.9854 - val_loss: 0.0590 - learning_rate: 0.0010
# Epoch 48/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9914 - loss: 0.0530 - val_accuracy: 0.9805 - val_loss: 0.0601 - learning_rate: 0.0010
# Epoch 49/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9886 - loss: 0.0552 - val_accuracy: 0.9854 - val_loss: 0.0579 - learning_rate: 0.0010
# Epoch 50/50
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9908 - loss: 0.0520 - val_accuracy: 0.9805 - val_loss: 0.0587 - learning_rate: 0.0010

# %%
# %tensorboard --logdir log_dir
# Out:
# Reusing TensorBoard on port 6007 (pid 1184), started 0:00:17 ago. (Use '!kill 1184' to kill it.)
#       <iframe id="tensorboard-frame-efe99f6dae97adcf" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-efe99f6dae97adcf");
#           const url = new URL("/", window.location);
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !kill 1184
# Out:
# /opt/conda/lib/python3.10/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
